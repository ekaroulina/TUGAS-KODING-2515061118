# %% [markdown]
# Norms

# %%
import numpy as np

# %%
# Membuat vektor x dengan ukuran 3x1
x = np.array([18, 11, 8])
x
# Out:
# array([18, 11,  8])

# %%
# Menghitung L2 Norm (Panjang Vektor) dari vektor x
(18**2 + 11**2 + 8**2)**(1/2)
# Out:
# 22.561028345356956

# %% [markdown]
# Unit Vectors

# %%
# Membuat vektor v
v = np.array([3, 4])

# Menghitung L2 Norm (Panjang Vektor) vektor v
norm = np.linalg.norm(v)

# Menghitung unit vector
unit_v = v / norm

# tampilkan unit vector dari vector v

print("Vektor asli:", v)
print("Panjang vektor:", norm)
print("Unit vector:", unit_v)
print("Panjang unit vector:", np.linalg.norm(unit_v))
# Out:
# Vektor asli: [3 4]
# Panjang vektor: 5.0
# Unit vector: [0.6 0.8]
# Panjang unit vector: 1.0
